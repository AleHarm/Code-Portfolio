# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/porterjenkins/byu-cs474/blob/master/lab8_self_attention.ipynb)

# %% [markdown]
# # The Transformer and Attention
#
# In this lab, you will create a transformer. We will be performing the same task as the RNN lab: generating text using a decoder-only scheme. Instead of a character-by-character approach, we will do token-by-token (which is similar to word-by-word) generation.

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762)
# Note: these use the encoder-decoder approach. This is only necessary if we have a separate input and output sequence, like in a translation task. Here, our input and output sequence are the same, therefore we will use a decoder-only approach.
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/

# %% [markdown]
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import math, copy, time, collections

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Running on {}".format(device))
# Out:
# Running on cuda

# %% [markdown]
# ---
#
# # Examining the Dataset
#
# As always, we will begin by examining our data.
#
# Since we are performing the same task as the previous lab, we can use the same dataset.

# %%
import unidecode
with open('C:/Users/School/Documents/CS 474/Lab8/text_files/lotr.txt', 'r', encoding='utf-8-sig') as f:
    file = unidecode.unidecode(f.read())

# %% [markdown]
# ## Tokenization
#
# Unlike last lab, we don't want to process our input character-by-character. Characters generally don't contain much semantic meaning, while words do. To use words as the base unit for our model, we need to separate the text into a sequence of words. We'll use the `spaCy` library to tokenize our text so we don't have to.
#
# **NOTE:** If you were using a non-English language corpus, this lab should work just fine, but you will need to find a language-appropriate spaCy model.

# %%
import spacy

# %%
spacy_model = spacy.load('en_core_web_sm')
def tokenize(line):
  return [tok.text for tok in spacy_model.tokenizer(line)]

# %% [markdown]
# Now lets tokenize the whole file and print out random sections of tokens.

# %%
all_tokens = tokenize(file)
print("The file is {} tokens long".format(len(all_tokens)))
# Out:
# The file is 618270 tokens long

# %%
seq_len_words = 30
for _ in range(4):
  i = np.random.randint(len(all_tokens) - seq_len_words)
  seq = all_tokens[i:i+seq_len_words]
  print(seq)
  print(' '.join(seq))
  print()
# Out:
# [';', 'but', 'there', 'were', 'no', 'young', 'Ents', ',', 'no', 'saplings', '.', '\n', 'Altogether', 'there', 'were', 'about', 'two', 'dozen', 'standing', 'on', 'the', 'wide', 'grassy', 'floor', 'of', '\n\n\n\n\n', 'the', 'dingle', ',', 'and']
# ; but there were no young Ents , no saplings .
#  Altogether there were about two dozen standing on the wide grassy floor of
#
#
#
#
#  the dingle , and
#
# ['hosts', 'of', 'Mordor', 'lay', 'between', 'us', ',', "'", '\n', 'said', 'Aragorn', '.', "'", 'Did', 'I', 'not', 'say', 'so', 'at', 'the', 'Hornburg', '?', "'", '\n\n', "'", 'So', 'you', 'spoke', ',', "'"]
# hosts of Mordor lay between us , '
#  said Aragorn . ' Did I not say so at the Hornburg ? '
#
#  ' So you spoke , '
#
# ['.', 'The', 'house', 'at', '\n', 'Crickhollow', 'stood', 'silent', '.', 'Fatty', 'Bolger', 'opened', 'the', 'door', 'cautiously', 'and', 'peered', '\n', 'out', '.', 'A', 'feeling', 'of', 'fear', 'had', 'been', 'growing', 'on', 'him', 'all']
# . The house at
#  Crickhollow stood silent . Fatty Bolger opened the door cautiously and peered
#  out . A feeling of fear had been growing on him all
#
# ['No', 'harp', 'is', 'wrung', ',', 'no', 'hammer', 'falls', ':', '\n\n', 'The', 'darkness', 'dwells', 'in', 'Durin', "'s", 'halls', '\n', 'The', 'shadow', 'lies', 'upon', 'his', 'tomb', '\n', 'In', 'Moria', ',', 'in', 'Khazad']
# No harp is wrung , no hammer falls :
#
#  The darkness dwells in Durin 's halls
#  The shadow lies upon his tomb
#  In Moria , in Khazad

# %% [markdown]
# We are using a simple tokenizer, which mostly just splits at word boundaries, but also splits off punctuation and some compound words ("don't" is tokenized as "do", "n't"). More complex tokenizers may split parts of words as well (separating roots, prefixes, and suffixes).

# %% [markdown]
# Like in the RNN lab, we can't use these tokens as input to our model yet: we need to turn them into numerical data.
# Eventually we'll use word embeddings (`nn.Embedding`), but for now, we can turn them into indices for our embedding layer.
# We can build a vocabulary using the tokens in our corpus.
# Any word that appears less than `MIN_FREQ` times will be interpreted as an `<UNK>` (unknown) token, as we shouldn't expect our model to learn such an infrequent token.
# Even if we set `MIN_FREQ=1`, our model can encounter new tokens after training.

# %% [markdown]
# We have provided a custom vocabulary class. This is based on the functionality of torchtext.vocab, but torchtext is depreciated and cannot be imported with newer versions of PyTorch.

# %%
class Vocab:
    def __init__(self, tokens, special_tokens=['<UNK>'], min_freq=0, default_token='<UNK>'):
        counter = collections.Counter()
        counter.update(tokens)
        self.vocab_list = [token for token, count in counter.items() if count >= min_freq]
        if default_token not in special_tokens:
            special_tokens.append(default_token)
        self.vocab_list += special_tokens
        # Reverse vocab list w/ dictionary
        self.vocab_dict = dict([(token, i) for i, token in enumerate(self.vocab_list)])
        self.default_idx = self.vocab_dict[default_token]

    def idx_to_token(self, i):
        return self.vocab_list[i]

    def idx_tensor_to_tokens(self, indices):
        return [self.vocab_list[i.item()] for i in indices]

    def token_to_idx(self, token):
        try:
            return self.vocab_dict[token]
        except KeyError:
            return self.default_idx

    def tokens_to_idx_list(self, text):
        return [self.token_to_idx(token) for token in text]

    def __len__(self):
        return len(self.vocab_list)

# %%
UNK_TOKEN = '<UNK>'
vocab = Vocab(all_tokens, [UNK_TOKEN], min_freq=2, default_token=UNK_TOKEN)
print("Vocabulary contains {} unique tokens.".format(len(vocab)))
# Out:
# Vocabulary contains 9523 unique tokens.

# %% [markdown]
# This vocab object gives us a dictionary that we can use to transform tokens between string and integer representations.

# %%
print(f"Token Index {5} => {vocab.idx_to_token(5)}")
print(f"Token RINGS => {vocab.token_to_idx('RINGS')}")
# Out:
# Token Index 5 => RINGS
# Token RINGS => 5

# %% [markdown]
# Note that the vocabulary is case-sensitive. For the Lord of the Rings corpus, "Gandalf" is in the vocabulary, but "gandalf" is not and defaults to the "\<UNK\>" token.

# %%
print("Gandalf => {} ({})".format(vocab.idx_to_token(vocab.token_to_idx('Gandalf')), vocab.token_to_idx("Gandalf")))
print("galdalf => {} ({})".format(vocab.idx_to_token(vocab.token_to_idx('gandalf')), vocab.token_to_idx("gandalf")))
# Out:
# Gandalf => Gandalf (315)
# galdalf => <UNK> (9522)

# %% [markdown]
# Now we have all the tools to implement the `LOTRDataset`.
# Use the sequence of Lord of the Rings tokens (`lotr_token_sequence`) and the `vocab` object to return sequences of token indices.
# `.__getitem__(self, i)` should output an input sequence of token ids `token_ids[i : i+chuck_length]` and a target sequence of token ids `token_ids[i+1 : i+chuck_length+1]`.

# %%
class LOTRDataset(Dataset):
    def __init__(self, lotr_token_sequence, vocab, chunk_length):
        self.lotr_token_sequence = lotr_token_sequence
        self.vocab = vocab
        self.chunk_length = chunk_length
        self.token_ids = self.vocab.tokens_to_idx_list(self.lotr_token_sequence)

    def __getitem__(self, i):
        input_sequence = self.token_ids[i : i + self.chunk_length]
        target_sequence = self.token_ids[i + 1 : i + self.chunk_length + 1]
        
        return torch.tensor(input_sequence, dtype=torch.long), torch.tensor(target_sequence, dtype=torch.long)

    def __len__(self):
        return len(self.token_ids) - self.chunk_length

CHUNK_LENGTH = 128
BATCH_SIZE = 64

dataset = LOTRDataset(all_tokens, vocab, CHUNK_LENGTH)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
input_idxs, target_idxs = next(iter(dataloader))
print('Input Token Ids:', input_idxs[0, :32])
print('Target Token Ids:', target_idxs[0, :32])
print('\nInput Tokens:', vocab.idx_tensor_to_tokens(input_idxs[0, :32]))
print('\nTarget Tokens:', vocab.idx_tensor_to_tokens(target_idxs[0, :32]))
# Out:
# Input Token Ids: tensor([  24,  786, 2314,  185, 1394,   77,  390,  209,  119, 6317,  366, 1379,
#           77,    0,   24, 2252,  185, 2063,  279,   24, 3628,  654,   11,   24,
#         1337,  185, 3832, 2997,  185,    0,  284,  528])
# Target Token Ids: tensor([ 786, 2314,  185, 1394,   77,  390,  209,  119, 6317,  366, 1379,   77,
#            0,   24, 2252,  185, 2063,  279,   24, 3628,  654,   11,   24, 1337,
#          185, 3832, 2997,  185,    0,  284,  528,  326])
#
# Input Tokens: ['the', 'great', 'tree', ',', 'deep', 'in', 'thought', ';', 'and', 'Legolas', 'stood', 'alone', 'in', '\n', 'the', 'open', ',', 'looking', 'towards', 'the', 'profound', 'shadow', 'of', 'the', 'wood', ',', 'leaning', 'forward', ',', '\n', 'as', 'one']
#
# Target Tokens: ['great', 'tree', ',', 'deep', 'in', 'thought', ';', 'and', 'Legolas', 'stood', 'alone', 'in', '\n', 'the', 'open', ',', 'looking', 'towards', 'the', 'profound', 'shadow', 'of', 'the', 'wood', ',', 'leaning', 'forward', ',', '\n', 'as', 'one', 'who']

# %% [markdown]
# If you implemented the dataset correctly, your target tokens/indices should be one token/index ahead of the input tokens/indices.

# %% [markdown]
# # Model
#
# For the transformer model, we'll use a decoder-only scheme. We do not need an encoder because the output sequence and input sequence are the same.
# Our model will taken in a sequence of token ids (shape `(B, S)`) and map them to a sequence of next token predictions (shape `(B, S, C)`) where the last dimension `C` is an unnormalized distribution over the class of tokens.

# %% [markdown]
# ## Input Embeddings
#
# The transformer model takes in a sequence of token ids (shape `(B, S)`) and maps them into feature vectors (shape `(B, S, Z)`). This is a two part process involving scaled embeddings and positional encodings.
#
# ### Scaled Embedding
#
# The typical way to map ids to feature vectors is with an `nn.Embedding` layer, but because the vocab size is so large we should scale the embeddings so they are different enough from each other.
# Implement `ScaledEmbedding` by instantiating an `nn.Embedding` layer and in the `.forward()` scaling the embedding layer's output by the by the square root of its embedding dimension.

# %%
class ScaledEmbedding(nn.Module): 
    def __init__(self, num_embeddings, embedding_dim):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim)
        self.scale = math.sqrt(embedding_dim)

    def forward(self, x):
        return self.embedding(x) * self.scale

# %% [markdown]
# ### Positional Encoding
#
# The second part of creating our input embeddings is to use positional encodings.
# Since our model contains no recurrence and no convolution, in order for the model to know the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.
# To this end, we add "positional encoding" information to the input embeddings.
# The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.
# There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# We will use sine and cosine functions of different frequencies (this is from the "Attention Is All You Need" paper):
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.
#
# **Note:** *Everything has been implemented for you, just read this section to understand the utility behind positional encodings.*

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)],
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(torch.zeros(1, 100, 20))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
plt.show()

# %% [markdown]
# ## Attention
#
# We now implement the core mechanism behind the transformer: Attention.
#
# Attention operates on queries and key-value pairs. The query tensor can be thought of as an input that is transformed into a linear combination of the value tensors. The weights of this linear combination are determined by how similar the query is to the corresponding key tensor. This operation is performed by "scaled dot product attention" or simply `attention()`.
#
# Our transformer model will use different representations of our input embeddings to form query, key, and value tensors. Attention will help the model determine what tokens to focus on and how to represent the tokens.
#
# Implement `attention` below.

# %% [markdown]
# ![attenton.png](data:image/png;base64,...)

# %%
def attention(query, key, value, mask=None):
    scores = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(query.size(-1))
    
    if mask is not None:
        scores = scores + mask

    attention_weights = F.softmax(scores, dim=-1)
    
    output = torch.matmul(attention_weights, value)

    return output

# %% [markdown]
# PyTorch has an implementation of [scaled dot product attention](https://pytorch.org/docs/stable/generated/torch.nn.functional.scaled_dot_product_attention.html). Use `F.scaled_dot_product_attention` with `mask=None` to verify that your attention module is correctly implemented.

# %%
q = torch.randn(12, 200, 64)
k = torch.randn(12, 200, 64)
v = torch.randn(12, 200, 64)
assert torch.allclose(attention(q, k, v, None), F.scaled_dot_product_attention(q, k, v, None), rtol=1e-5, atol=1e-6)

# %% [markdown]
# ## Masking
#
# Forget the batch dimension at the moment and assume that our input tensors `(Q, K, V)` for the `attention` function are of shape `(S, Z)`, where `S` is the sequence length and `Z` is the feature size. The matrix multiplication with softmax on `Q` and `K`, i.e. `softmax(QK^T)`, gives us an `(S, S)` matrix where row $i$ is a probability distribution over which tokens in the sequence are important for the learning task. If our task is to predict the next token (e.g. word), then the transformer could easily cheat by having token $i$ look at token $i+1$.
#
# <!-- We can use masking to avoid having to do recurrent inputs when training. Instead, we can predict the next word in the sequence at each step in the sequence. But there's an issue: if  -->
#
# For example, if we get the sequence `I am very happy today .` as input, the transformer can just look at the next token and predict: `am very happy today . ---`. If our model learns this, it won't work in practice because we don't have the whole sequence when generating text.
#
# The only time our model mixes information between tokens is in the attention layers. In order to perform attention so that a token embedding can only look itself and the tokens to the left of it, we create a mask that blocks out future information.
#
# `       I____ am___ very_ happy today .____`
#
# `I____: TRUE_ FALSE FALSE FALSE FALSE FALSE`
#
# `am___: TRUE_ TRUE_ FALSE FALSE FALSE FALSE`
#
# `very_: TRUE_ TRUE_ TRUE_ FALSE FALSE FALSE`
#
# `happy: TRUE_ TRUE_ TRUE_ TRUE_ FALSE FALSE`
#
# `today: TRUE_ TRUE_ TRUE_ TRUE_ TRUE_ FALSE`
#
# `.____: TRUE_ TRUE_ TRUE_ TRUE_ TRUE_ TRUE_`
#
#
# This means every token right of the current token should have a probability of zero.
# This is accomplished by setting their logits to $- \infty$ (or really small) so that the softmax results in them being zero.
# Implement the `create_mask` function to output an `(S, S)` matrix with a value of 0 on the diagonal and below (i.e. everywhere that is True in the matrix above) and a value of `-torch.inf` above the diagonal (i.e. everwhere that is False in the matrix above).
#
# **Tip:** Use `torch.full()` to create an `(S, S)` matrix full of `-torch.inf` values and then use `torch.triu()` to set the appropriate values to zero.

# %%
def create_mask(sequence_length):
    mask = torch.full((sequence_length, sequence_length), float('-inf'))
    mask = torch.triu(mask, diagonal=1)
    return mask.to(device)

# %% [markdown]
# You should print out your mask to make sure it is correct, but the function below is a visual test of `create_mask` working with softmax.
# Before masking we have probabilities across the entire sequence, but after masking you should have probabilities:
# $$\begin{bmatrix} 1 & 0 & 0 & 0 \\ .5 & .5 & 0 & 0 \\ .33 & .33 & .33 & 0 \\ .25 & .25 & .25 & .25  \end{bmatrix}$$

# %%
def viz_create_mask():
    sequence_length = 4
    mask = create_mask(sequence_length) 
    logits = torch.ones((sequence_length, sequence_length)).to(device)
    
    print("Before masking:")
    print(torch.softmax(logits, dim=-1))
    
    print("\nAfter masking:")
    print(torch.softmax(logits + mask, dim=-1))

viz_create_mask()
# Out:
# Before masking:
# tensor([[0.2500, 0.2500, 0.2500, 0.2500],
#         [0.2500, 0.2500, 0.2500, 0.2500],
#         [0.2500, 0.2500, 0.2500, 0.2500],
#         [0.2500, 0.2500, 0.2500, 0.2500]], device='cuda:0')
#
# After masking:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500]], device='cuda:0')

# %% [markdown]
# The masking makes it so we don't have to do recurrent inputs when we train: we can predict on all the target tokens on one pass instead of doing one forward pass for each token.

# %% [markdown]
# ### Multi-Headed Attention Module
#
# `attention()` by itself has no learnable parameters, in order to learn how to use attention we will create linear layers that turn the input sequence(s) into queries, keys, and values. The transformer learns how to use attention by learning the parameters of these linear layers.
#
# Performing one round of attention is like having a convolution layer with a single channel: it can only look for one type of feature. Just like with using multiple learned filters for convolutions and using multiple neurons for linear layers, we will perform multiple rounds of attention on the same input (with the only difference being the parameters in the linear layers). We refer to this as multi-headed attention: each head performs attention on one set of queries, keys, and values. At the end of the module, we combine the information from each head.
#
# Create a parameterized multi-headed attention module as described in described in [Attention is All You Need (Vaswani et al.)](https://arxiv.org/pdf/1706.03762.pdf). Note that each head will need separate parameters, as well as each query, key, and value. So you should have $3h$ sets of parameters, plus the final linear layer.
#
# To ensure the computation costs don't increase h-times, you can give each head an embedding dimension size of `d_model // h`. When you concatenate them together at the end, you'll still end up with an embedding of size `d_model`.

# %% [markdown]
# ![mh_attention.png](data:image/png;base64,...)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model):
        super().__init__()
        self.h = h
        self.d_model = d_model
        self.d_head = d_model // h

        self.q_linear = nn.ModuleList([nn.Linear(d_model, self.d_head) for _ in range(h)])
        self.k_linear = nn.ModuleList([nn.Linear(d_model, self.d_head) for _ in range(h)])
        self.v_linear = nn.ModuleList([nn.Linear(d_model, self.d_head) for _ in range(h)])

        self.out_linear = nn.Linear(d_model, d_model)

    def forward(self, q_seq_embedding, kv_seq_embedding, mask):

        all_heads_output = []
        for i in range(self.h):
            Q = self.q_linear[i](q_seq_embedding)
            K = self.k_linear[i](kv_seq_embedding)
            V = self.v_linear[i](kv_seq_embedding)
            
            head_output = attention(Q, K, V, mask)
            all_heads_output.append(head_output)
        
        concat_output = torch.cat(all_heads_output, dim=-1)
        
        output = self.out_linear(concat_output)

        return output

# %% [markdown]
# ## Decoder
#
# The decoder model is responsible for predicting the next character of the target or output sequence. For the text generation task, there is no input sequence or context that needs to be encoded (refer to the "Attention Is All You Need" diagram), so we have provided a diagram of the decoder-only architecture below.
#
# The core module in the decoder are $N$ identical stacked layers, which you will implement as `DecoderLayer`.
# The input `x` to a `DecoderLayer` is fed through a multi-headed attention layer.
# Note that `x` is the source of the keys, queries, and values.
# The output of the attention module is then added to `x` and we perform layer normalization (via `nn.LayerNorm`).
# This output is then fed to a feed forward network (refer to section 3.3 in the [Attention Is All You Need](https://arxiv.org/pdf/1706.03762)).
# The output of the feed forward network is then added to its input and you perform another layer normalization (so instantiate two layer norm layers).
#
# Before you perform an "add and norm" operation, you should apply a dropout (`nn.Dropout`) to the output (refer to section 5.4).

# %% [markdown]
# ![decoder_only_architecture.png](data:image/png;base64,...)

# %%
import torch
import torch.nn as nn

class DecoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, h, dropout=0.1):
        super().__init__()

        self.multihead_attention = MultiHeadedAttention(h, d_model)

        self.ffn = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model)
        )

        self.layer_norm1 = nn.LayerNorm(d_model)
        self.layer_norm2 = nn.LayerNorm(d_model)

        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)

    def forward(self, x, mask):
        attention_output = self.multihead_attention(x, x, mask)
        x = self.layer_norm1(x + self.dropout1(attention_output))

        ffn_output = self.ffn(x)
        x = self.layer_norm2(x + self.dropout2(ffn_output))

        return x

# %% [markdown]
# Implement the `TransformerDecoder` (the entire model in the figure above). It should contain a `ScaledEmbedding`, a `PositionalEncoding`, `N` `DecoderLayer` modules, and a `nn.Linear`.
# Embed the input token ids with the `ScaledEmbedding` layer followed by the `PositionalEncoding` layer.
# Each `DecoderLayer` is stacked, feeding its output as the next layer's input.
# The output of our stacked `DecoderLayer`s should be converted into predictions (logits) of the next tokens through a `nn.Linear` layer.
# These predictions can then be compared to the true sequence with cross entropy loss (so do not apply softmax because the cross-entropy loss will do it), like any classification problem.
#
# **Note:** *We performed Xavier initialization on the network parameters because it improved learning speed and performance.*

# %%
import torch
import torch.nn as nn

class TransformerDecoder(nn.Module):

    def __init__(self, vocab_size, N=4, d_model=256, d_ff=512, h=4, dropout=0.1):

        super().__init__()

        self.embedding = ScaledEmbedding(vocab_size, d_model)

        self.positional_encoding = PositionalEncoding(d_model, dropout)

        self.decoder_layers = nn.ModuleList([
            DecoderLayer(d_model, d_ff, h, dropout) for _ in range(N)
        ])

        self.fc_out = nn.Linear(d_model, vocab_size)

        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)

    def forward(self, x, mask):

        x = self.embedding(x)

        x = self.positional_encoding(x)

        for layer in self.decoder_layers:
            x = layer(x, mask)

        logits = self.fc_out(x)

        return logits

# %% [markdown]
# ## Training and Inference
#
# Remember the transformer's input is a LongTensor with shape `(B, S)`. and its output is a FloatTensor with shape `(B, S, C)`, where `C` is the number of classes, representing the sequence of next predicted tokens.
# To generate text from our transformer given a priming token id, you input the sequence of one into the transformer and sample the last token prediction in the sequence, which is concatenated with the priming token id and fed back into our transformer and we repeat the process.
#
# For example, our starting input of shape `(B, S=1)` (assuming we are using a single priming token) will give us an output of shape `(B, S=1, C)`.
# We sample along the `C`-dimension to get our next token id and concatenate it with our priming token id sequence.
# This means our next starting input is of shape `(B, S=2)` and the output will be `(B, S=2, C)`.
# We only need to sample the last token prediction, i.e. `output[:, -1]`, because we have already sampled `output[:, 0]` in the previous step.
#
# Implement the `generate()` function below to generate a sequence of tokens from a transformer model.

# %%
import torch
import torch.nn.functional as F

@torch.no_grad()
def generate(x, model, pred_length, temperature=0.8):
    
    generated_sequence = x
    
    for _ in range(pred_length):
        mask = create_mask(generated_sequence.size(1)).to(x.device)

        logits = model(generated_sequence, mask)
        
        logits = logits[:, -1, :]
        
        logits /= temperature
        
        probs = F.softmax(logits, dim=-1)
        next_token = torch.multinomial(probs, 1)
        
        generated_sequence = torch.cat((generated_sequence, next_token), dim=1)
    
    return generated_sequence

# %% [markdown]
# Just like in the RNN lab, we want to print out our text generation evaluation throughout training, so we can better understand how the model is working.
# Just like before, we provide a starting input and have the model predict the next character until we have generated enough text.
# Note that this evaluation function will be very similar to the one using the RNN. Unlike the RNN, the transformer has no memory, so it must take in the entire sequence each time.

# %%
eval_start_tokens = ["The", "Where", "fight", "Gandalf"]
EVAL_START_TOKEN_IDS = torch.tensor([[vocab.token_to_idx(start_token)] for start_token in eval_start_tokens]).long()
def evaluate(model):
    model.eval()
    inference_batch = generate(EVAL_START_TOKEN_IDS.to(device), model, CHUNK_LENGTH)
    for inference_tokens in inference_batch:
        pred_tokens = vocab.idx_tensor_to_tokens(inference_tokens)
        print(' '.join(pred_tokens))
        print('='*200)
    print()
    model.train()

evaluate(TransformerDecoder(len(vocab)).to(device))
# Out:
# The folly crowd afterwards pursued bolt multiply Ancient splinter hundred paddles cross Tookland beads lit dire reluctant ordinary caps northerly stroked Narsil dreamed butt mercy vigil relation mother somehow flicker bristling terrified true rag Gondolin Be legendary waggons Curunnr cheers appearances appointed forging sleep giants back grew snoring dogs achieve broken -light arid herds Such seconds gentle pouch telling halt Kill wains world unpopular angrily uplands Grishnbkh dismay Cleft counter overjoyed must jerkin hundred stride grant aisles stunned keenly satisfy leaving childhood muddy lost mounds stretch shave inadequate graves dates brooch dancing record thirty labels beds scanty lakes crumpled beforehand quivering account pier Combe picnic script murmur seats bothered pay particular she Thou rabbits fearless spring BOOK haven am shun mournful testing leagues ruin Falls home besieged Fie fearful
# ========================================================================================================================================================================================================
# Where Mardil clasped Looking splendidly rendered variety meant fated overjoyed gateway shows spite keenly played sniffed cake Verily ruin Paladin stools keel Lothlurien northward dint badgers Fady weeks attempt cheer suspiciously thereafter bowstrings horribly scouts Phial suitable restlessly aiding Funny Books singer overshadowed Mortal whisperings pass flaring often bustling questioned practice halts Flight blindfolded strained footfall bell expression desperation drier thee road fuel slowcoach roast keenly liable know-- names plates stifling dread none elders chanced clouded Thain words separated character blurred rags incoming these eagle Higher barriers shielding save Many stink Celebrimbor disturbed constantly packed painfully Jowyn harmless spells marble roots Whither inch advance brim swear hills padded toiling who obtain amends Word alarm heights loathsome tiny barely smile swung treasured overhead rams Welcome jerk nod striving unwisely confusing
# ========================================================================================================================================================================================================
# fight hardly says Sssh reckless starving tied treasured tottering needle fling precious then pelts Ring barrel liquor queerest captivity spun robed besides anxiously approved feigned seemed pushing wilt realized rooms tributary Fields gladly sensed pans strangest vomit Anyway scorn shallow slabs tunnelled twisting lingering trowels played
#
#
#
#
#  harp Citadel grandmother shaping boiled curses gives Flere erred measure Burrowses flurry chap ray pressed teacher required valley chambers Country bewilderment slabs voyage joined approval experience mournful Forty business clean thundered Fie Death knoll harmless -roof Ethir corn spare crushed chip hardier miruvor expression worse anon scrabbling manger Beneath pretending risk touching tongs pages worth delighting crafts stale tame Year Evendim sloped Harfoots hearties visited falter dear Its Iarwain burden unadorned rottenness Only ringing hardest surging horseback crumbs yellow nicely beginning Inn
# ========================================================================================================================================================================================================
# Gandalf Bolgers overshadowed rippled hardened Grond reference twined moved brushing dotted caressed oaths knoll Ashen lamentation battle Harfoots mistakes discovered developed whipped exceedingly nibbled hom friendship battlement signal some upstart Nenya forefinger gel Ahead overlooked lovely slew delight lengthened survivors Mountains cake letters usually Elvish rule treasured needs bolsters Cottons loveliness know-- background likewise Firstborn brooch spying upstart withstand crowned finally stick halfling unusual fingered laughter goods Barliman sickness mere invitation grimly no kinsmen coastlands snare everlasting Ele engulf Ciril cautious vastness shuddering Buck strive Lonely thundered Sneak roof Mill 1420 uses goods perished delightful punishment bred seek Hoy revive Goldberry S.-B.s derry face stretch stir rutted torrent knit drank fowl bird Farewell thain rolls second Wood stretched musical sly brighter or Lebennin dire Fossarnach 6 quality Hullo Brandy
# ========================================================================================================================================================================================================

# %% [markdown]
# Now implement the `train` function to optimize your transformer model for `n_optimization_steps` and return the losses over time.
# At every `eval_interval` print the current training loss and use `evaluate` to generate some text.
#
# **Note:** *Remember that CrossEntropyLoss expects `y_hat.shape == (B*S, C)` and `y_truth.shape == (B*S,)` or `y_hat.shape == (B, C, S)` and `y_truth.shape == (B, S)`.*

# %%
import torch
import torch.nn as nn

def train(model, optimizer, dataloader, n_optimization_steps, eval_interval):

    loss_fn = nn.CrossEntropyLoss(label_smoothing=0.1)
    
    losses = []
    
    for step in range(n_optimization_steps):
        model.train()
        
        for batch in dataloader:
            input_tokens, target_tokens = batch

            input_tokens = input_tokens.cuda()
            target_tokens = target_tokens.cuda()
            
            mask = create_mask(input_tokens.size(1)).to(input_tokens.device)
            
            optimizer.zero_grad()
            
            logits = model(input_tokens, mask)
            
            logits = logits.view(-1, logits.size(-1))
            target_tokens = target_tokens.view(-1)
            
            loss = loss_fn(logits, target_tokens)
            losses.append(loss.item())
            
            loss.backward()
            optimizer.step()
        
        if step % eval_interval == 0:
            print(f"Step {step}/{n_optimization_steps}, Loss: {loss.item()}")
            
            print("Generated text:")
            generated_text = evaluate(model)
            print(generated_text)
    
    return losses

# %% [markdown]
# Train your model. You want your final losses to be below 3.5.

# %%
model = TransformerDecoder(len(vocab), N=2, d_model=256, d_ff=512, h=8).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

losses = train(model, optimizer, dataloader, n_optimization_steps=5, eval_interval=1)
# Out:
# Step 0/5, Loss: 2.9093990325927734
# Generated text:
# The hythe of white stones and white stones . A thin dark smoke was lit
#  with torches disappear . Then , do you hear ready . " I go up and hunted the
#  long rumbling noise , as a girdle of stones . ' I wish I could see about my
#  eyes . I rode up . I am sure it are surprising - and golluml They looked
#  forward to the horror .
#
#  ' Yes , you have n't let us really like a spider , ' said the old
#  Elves , but <UNK> hobbits , angry , and afraid . ' If they want to be ,
#  then they 've failed , they began . They did not mean to go
# ========================================================================================================================================================================================================
# Where is you ? '
#
#  ' About the lowest <UNK> . '
#
#  ' A heavy <UNK> water , ' said Aragorn , ' and how many more
#  miles ? But now it 's gone far away Off we go . And anyway we see all
#  more than Sam would mean . That 's what I feared . '
#
#  ' Well , Sam , ' said Frodo . ' I 've heard the of that road , I should
#  make a log and Whatever danger may be on the high noon . '
#
#  ' Take care , ' said Frodo . ' Not yet . But come ! We 'll meet any tall
#  as we can , if we ca n't touch
# ========================================================================================================================================================================================================
# fight , and we ? scrawls that ores had put
#  hold in their debate who had counselled us that Minas Morgul should seek for
#  the defence of the Morgul .
#
#  ' And what did men say ? ' said Denethor ; ' but if it frail enough
#  anything , it would seem , we should make it be . It was night . Then it
#  was not dark , and not dead . I came in the blackness in his senses ,
#  became aware that there was a black prospect , and the hobbits present suddenly it seemed
#  too forgotten .
#
#  ' I would have done on our errand , ' said Frodo . ' I felt it on our
#
# ========================================================================================================================================================================================================
# Gandalf . ' I have made it ! ' he cried . ' If Saruman
#  was laid by him at his side , he would have thought he could come back to
#  his master , who had not . But how he had retreated , even and before he
#  reached the mouth of the tunnel ; and he thought he was Elessar , went back and
#  went back to the Black Land , and there was no word for some time .
#
#  But if he had heard them Noakes ; and his son was such more
#  more than half a Drogo 's weight than sunk in this land or a few ,
#  more that being discovered . They had a first throw
# ========================================================================================================================================================================================================
#
# None
# Step 1/5, Loss: 2.5998830795288086
# Generated text:
# The cool sun now Once again was riding over the
#  mountain - water ; they were alone and set soft , and a few leaves on their left .
#  The air seemed still and stuffy . When they forced their way at last into
#  the pathless land in mist , they breathed deep , and brought little grasses and
#  grey in the land , about living or living in places and bother .
#
#  Hirluin the morning , clad wife and Rosie to the Fair , and yellow
#  flowers to the stars ; and yellow in the morning sun sank , and her red
#  smouldering in eye ; for the grass was fading , even if rippling in the wind
#  was thick
# ========================================================================================================================================================================================================
# Where
#  was there ? '
#
#  ' It 's got an ore 's guess , ' said Sam , ' that 's the country . I want to come
#  back and find a fast asleep . '
#
#  ' I wish I could see you again . Do n't look ! ' said Gandalf . ' I am old .
#
#  ' I dream I have . I know , ' said Frodo . ' But I guess I learned that this
#  time , as long as long as I have here . Sleep ! '
#
#  It was one of the first time to keep awake , until the battle was fought
#  together and still I rode on . When the memory of Fare
# ========================================================================================================================================================================================================
# fight in the least . '
#
#  ' And who has G yet for sure , ' said Haldir .
#
#  ' It has long been too long to perceive the signs . Some are the name of
#  Elendil , though all dressed alike , and shorter and old . ' said
#  Aragorn . ' Let us ride and see that old man has an hour been out of the
#  South . '
#
#  ' It is your task to return hither from me , ' said Elrond . ' But
#  what will I say ? '
#
#  ' The others are bound up with him , ' said Frodo .
#
#  ' Do not know how our peril would take you on my eyes
# ========================================================================================================================================================================================================
# Gandalf were <UNK> . Even prefer swear on my
#  shall be made thudding ; and I do not speak to them by the Chamber of
#  Mazarbul ; and the twenty - first of the North - end , and the wizard - room
#  first Waymeet , first the Lockholes . The Boss is a year before they seem
#  known , and the ruffians call at Bag End . They took leave everything
#  failed , they fidgeted and looked uncomfortable . Strider turned and
#  turned his tail and had passed over the long uncertain path . The Ores had been borne
#  before .
#
#  It was a long list of the beginning of the Ores already written
#  and took out of the
# ========================================================================================================================================================================================================
#
# None
# Step 2/5, Loss: 2.5089271068573
# Generated text:
# The
#  terror was filled with grief and wonder with anger as it Footsteps went
#  down the Hill ; the globe came down inside of Pippin . At last saw door
#  Sam 's face glimmering and vanished . He held a ring , as if he had been held long
#  thought for a while . Then he shut his eyes and put uproar away down . Then
#  behind it , and joined by spite of Bilbo and took up , a strange feeling that
#  They did now take a clear song for the <UNK> hobbit , as they walked in the
#  quiet hours of the hollow of the village .
#
#  They kept a stone mere , <UNK> round and broad , and
# ========================================================================================================================================================================================================
# Where he
#  was all the other way , by the clouds <UNK> and flows on to
#  a stepping road towards the hills , from the <UNK> and then running towards the
#  mountains .
#
#  At last they reached the lake amid a shallow slopes of bare heads . This was no
#  ending , but the first time passed out of the dell , and without a
#  level space . The boats were drawn out of brown water and grey . Here was a
#  cliff , the water dripping sadly from the dark trough , and her hard , and
#  watched the lower .
#
#  At last they reached the bottom of the bank of a bed . Sam they turned and followed
# ========================================================================================================================================================================================================
# fight . '
#
#  ' <UNK> , I am called Strider , ' he answered , ' if I had heard
#  it in your heart . But I am strangely weary . I must rest a little . Alas ! I have
#  guessed how to help myself , since I reached Rivendell . Come on ! There is
#  much to tell how to say , Frodo ; and that when I have made a mind to
#  " that I was to say , a good deal of planning to go and saying
#  farewell to your haunts , we are Crickhollow year since April . We have constantly
#  chilled my heart . ' He was clutching at last , ' he replied ; but
# ========================================================================================================================================================================================================
# Gandalf . ' But you are still there , ' she said . ' He came to Faramir
#  the White Tower , and he was in a low voice . ' All your
#  chance or wisdom but for mercy . '
#
#  ' Then you will have learned more in you , ' said Saruman ; ' but neither
#  river and go Guesthouse in the building ; and so this was so through the
#  wings he was by impassable . ' There is no open gate into the Nameless Land ,
#  used up from below so far below faced beyond the rider . Immediately their
#  bedrooms , while your supper was glad , while they invitations were
#  chosen , and the Blindfold
# ========================================================================================================================================================================================================
#
# None
# Step 3/5, Loss: 2.465810775756836
# Generated text:
# The water was
#  also , mended to the window and out of the rouse suspicion ; but when
#  Gollum was talking to horn a cock - a - whoop uncomfortable . And
#  nothing , faster out his breeches , and found it was Fredegar in his
#  house . Then he <UNK> and turned back to the same time , and
#  gave way <UNK> .
#
#  ' I do not know how you have the time , ' said Frodo . ' I have n't got herb - master
#  this hurt and choose in my own fashion . And if he came to Frodo , he found
#  standing by the arm there was a broad - headed spear . As a As wrong
# ========================================================================================================================================================================================================
# Where is the master that leaf ? '
#
#  ' It is n't used for , ' said Frodo .
#
#  ' No , ' said Sam , coming back to the bottom . It was suddenly by a
#  foreseen and though when it Foes came to him down , they began to
#  show
#
#  good speed . The hours was before . In so dim and flat and an ominous
#  fall of the Dwimorberg willows was young . Frodo was dragged among the
#  stones tall bowmen , game by him with his eyes ; ' he laughed . ' It is
#  Elvish , or a Man Willow ! But this is not a king of motionless - prints . His
#  face is
# ========================================================================================================================================================================================================
# fight
#  for the first day of the march . The worth were now made ready for
#  a journey ; for the Enemy was fast westering as they rode , or by one or
#  promise to take the other . '
#
#  ' We must make for the thoughts of our journey , ' said Boromir . ' But I
#  fear that I have no counsel of you if you should not give the Ring to
#  the chain - spread from the pocket of his neck . There was still no gleam , and
#  in the middle of the great curve of Anduin , the Anduin , or within it
#  lay beyond the Anduin , and the ores made into a mist ,
# ========================================================================================================================================================================================================
# Gandalf was not
#  ready for the fallen asleep .
#
#  Frodo was busy with many thoughts of abreast and pursued by Elrond , to
#  put little watch upon the floor and looked back , and seemed to grow hovering
#  sleep . When forgetfulness came over him , he heard him told him came near , and
#  passing his reckoning the waking whole - wall was ready . spirit of Mordor ;
#  but it shrank away .
#
#  A long <UNK> of some way up that way , and saw it still
#  some large strong slanted on it , a small square patch of blue sky could be
#  seen . It was dimly lit , not worth too late , it Hundreds of
# ========================================================================================================================================================================================================
#
# None
# Step 4/5, Loss: 2.4506049156188965
# Generated text:
# The great cave was filled with a noise and soft singing ,
#  walking as taters .
#
#  ' Smjagol is the last time , ' said Sam .
#
#  Warm fall ; entirely stood in the hearts of Elendil rides in
#  battle , and still about them .
#
#  ' Here is the fallen horn , ' said Aragorn . ' <UNK> is madness . The people of
#  their friends ! And their friends are coming . Night is gone . The very warmth of
#  Out . I know my scorching flames . Yet what hope we saw the light that he was
#  the light that we were at hand now , and soon they saw the light pass ! All the
#  while
# ========================================================================================================================================================================================================
# Where the
#  night is come , if you come to the Ents , that is not what his thing is
#  to do . '
#
#  ' Then why did he stay in in the <UNK> , I have renew the old <UNK> of
#  Shire on the head between the Shire and Bree ; and in the Shire and to find
#  hear more about the food of telling you anything that he could do , if
#  you said that it was a joke about serious times . I wish I had
#  going to get out of my lids . '
#
#  ' All the same , ' said Frodo . ' You can hear more , and what is more ? Have you
#
# ========================================================================================================================================================================================================
# fight , with all seeing record of the day when the day 's march promised , and
#  hearts was silent , and then one amazed at last effort of seeing
#  his words in his ears , a new noise seemed suddenly to tremble , and then it
#  was turned to the heavy walls outside the passage , and the opened Receive it
#  once again . Through the shadow of the trees saw a glimmer that his eyes were
#  still shining , as if some gold could be smokes . His rushed up ,
#  and the tree - shadows seemed to him that light flickered and went
#  from the East and went wildly up at the distant hills . Aragorn halted and
#
# ========================================================================================================================================================================================================
# Gandalf . ' It
#
#  ' After a while , ' said Pippin . ' I have nearly got the rope and about
#  us . And if you were n't loathsome . The creature : we must have
#  endured it . It is a sad story and thing that made it hard to say . '
#
#  ' I think it is a strange fate that we should do , ' said Gandalf . ' The
#  wizard 's face was grave and sad about without a smile . ' I did not think of
#  harm , ' he said . ' And he added with a look - <UNK> <UNK> and
#
#
#
#
#  stronger and taking danger to the sense of doubt . But he has
# ========================================================================================================================================================================================================
#
# None

# %% [markdown]
# ## Plot losses

# %%
plt.plot(losses)
plt.title("Transformer Text Prediction Training")
plt.ylabel("Label-Smoothed Cross Entropy")
plt.xlabel("Training steps")
plt.show()
